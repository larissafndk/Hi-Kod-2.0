# %% [markdown]
# ÖDEV 1

# %%
maas=int(input("Maaş: "))
if maas<=10000 :
  print(maas-(maas*0.05))
elif maas<=25000 :
  print(maas-(maas*0.1))
elif maas<=45000 :
  print(maas-(maas*0.25))
else:
  print(maas-(maas*0.3))
# Out:
# Maaş: 15000
# 13500.0

# %% [markdown]
# ÖDEV 2

# %%
kullaniciAdi=input("Kullanıcı adı: ")
sifre=input("6 haneli şifre: ")
if len(sifre)==6:
  print("Hasabınız başarıyla oluşturuldu.")
else:
  print("Hesabınız oluşturulamadı.")

# %% [markdown]
# ÖDEV 3

# %%
kullaniciAdi=input("Kullanıcı adı: ")
a=False
while not a:
    sifre=input("6 haneli şifre: ")
    if 5<len(sifre)<10:
      a=True
      print("Hasabınız başarıyla oluşturuldu.")
    else:

      print("Lütfen girdiniz şifre 5 haneden az 10 haneden fazla olmasın!")
# Out:
# Kullanıcı adı: abc
# 6 haneli şifre: 1
# Lütfen girdiniz şifre 5 haneden az 10 haneden fazla olmasın!
# 6 haneli şifre: 2562356
# Hasabınız başarıyla oluşturuldu.

# %% [markdown]
# ÖDEV 4

# %%
sifre="12345"
hak=3
while hak>0:
  a=input("sifre: ")
  if a== sifre:
    print("Giriş yapıldı")
    break
  else:
    print("Giriş yapılamadı. Tekrar deneyiniz")
    hak -=1
# Out:
# sifre: 12
# Giriş yapılamadı. Tekrar deneyiniz
# sifre: 12345
# Giriş yapıldı
