# %% [markdown]
# ÖDEV 1

# %%
b="123"
d=int(b)
print(d)
# Out:
# 123

# %% [markdown]
# ÖDEV 2

# %%
ahmet=15
ali=35
zeynep=67
krslstrm = zeynep>ali>ahmet
print(krslstrm)
# Out:
# True

# %% [markdown]
# ÖDEV 3

# %%
a=int(input("Sayi: "))
b=int(input("Sayi: "))
toplam=a+b
cıkarma=a-b
carpma=a*b
bolme=a/b
print(toplam,cıkarma,carpma,bolme)
# Out:
# Sayi: 15
# Sayi: 3
# 18 12 45 5.0

# %% [markdown]
# ÖDEV 4

# %%
isim=input("isim: ")
yas=int(input("yas: "))
meslek=(input("meslek: "))
print(isim,yas,meslek)
# Out:
# isim: a
# yas: 15
# meslek: b
# a 15 b

# %% [markdown]
# ÖDEV 5

# %%
atama="Hi-Kod Veri Bilimi Atölyesi"
a=atama.split(" ")
b=atama.upper()
c=atama.lower()
print(a)
print(b)
print(c)
# Out:
# ['Hi-Kod', 'Veri', 'Bilimi', 'Atölyesi']
# HI-KOD VERI BILIMI ATÖLYESI
# hi-kod veri bilimi atölyesi

# %% [markdown]
# ÖDEV 6

# %%
sayi = "0123456789"
cift = ""
tek= ""
for i in sayi:
    if i.isdigit():
        if int(i) % 2 == 0:
            cift += i
        else:
            tek += i
print("Çift sayılar:", cift)
print("Tek sayılar:", tek)
# Out:
# Çift sayılar: 02468
# Tek sayılar: 13579
